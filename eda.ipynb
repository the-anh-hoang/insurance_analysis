# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load CSV file
csv_file_path = 'IHME-GBD_2021_DATA-72716b14-1/IHME-GBD_2021_DATA-72716b14-1.csv'
csv_data = pd.read_csv(csv_file_path)

# Load Excel files
excel_file_paths = [
    'nhe23-tables/new table 1 total expenditures.xlsx',
    'nhe23-tables/new table 2 expenditures total amount.xlsx',
    'nhe23-tables/new table 3 source of funds.xlsx',
    'nhe23-tables/new table 5 type of sponsors.xlsx'
]

excel_data = {}
for file_path in excel_file_paths:
    excel_data[file_path] = pd.read_excel(file_path)

# Display the data
print("CSV Data:")
print(csv_data.head())
# Out:
# CSV Data:
#   measure_name  cause_id                               cause_name metric_name  \
# 0       Deaths       410                                Neoplasms      Number
# 1       Deaths       410                                Neoplasms        Rate
# 2       Deaths       344  Neglected tropical diseases and malaria      Number
# 3       Deaths       344  Neglected tropical diseases and malaria        Rate
# 4       Deaths       626                Musculoskeletal disorders      Number
#
#    year            val          upper          lower
# 0  1980  451711.372800  463715.356900  429850.261000
# 1  1980     196.520742     201.743174     187.009885
# 2  1980     125.931132     136.190930     115.011189
# 3  1980       0.054787       0.059251       0.050037
# 4  1980    4875.554196    5017.673641    4627.440970

# %%
print("\nExcel Data:")
for file_path, data in excel_data.items():
    print(f"\nData from {file_path}:")
    print(data.head())
# Out:
# Excel Data:
#
# Data from nhe23-tables/new table 1 total expenditures.xlsx:
#    Year  Nationa_Health_Expenditures _Billions  \
# 0  1980                                  253.2
# 1  1990                                  718.7
# 2  2000                                 1366.0
# 3  2001                                 1483.4
# 4  2002                                 1631.0
#
#    Health_Consumption_Expenditures_Billions  Personal_Health_Care_Billions  \
# 0                                     232.7                          214.3
# 1                                     670.2                          611.9
# 2                                    1280.3                         1156.5
# 3                                    1393.4                         1256.5
# 4                                    1529.6                         1365.5
#
#    Government_Administration_and_Net_Cost_of_Health_Insurance_Billions  \
# 0                                               11.9
# 1                                               38.3
# 2                                               80.7
# 3                                               90.1
# 4                                              111.9
#
#    Government_Public_Health_Activities_Billions   Investment_Billions
# 0                                           6.4                  20.6
# 1                                          20.0                  48.6
# 2                                          43.0                  85.7
# 3                                          46.8                  90.0
# 4                                          52.2                 101.5
#
# Data from nhe23-tables/new table 2 expenditures total amount.xlsx:
#    Year  National_Health_Expenditures_Billions  \
# 0  1980                                  253.2
# 1  1990                                  718.7
# 2  2000                                 1366.0
# 3  2001                                 1483.4
# 4  2002                                 1631.0
#
#    Health_Consumption_Expenditures_Billions  Personal_Health_Care_Billlions  \
# 0                                     232.7                           214.3
# 1                                     670.2                           611.9
# 2                                    1280.3                          1156.5
# 3                                    1393.4                          1256.5
# 4                                    1529.6                          1365.5
#
#    Hospital_Care_Billions  Professional_Services_Billions  \
# 0                   100.5                            64.5
# 1                   250.4                           207.9
# 2                   415.5                           387.0
# 3                   449.4                           420.7
# 4                   486.5                           454.7
#
#    Physician_and_Clinical_Services_Billions  \
# 0                                      47.7
# 1                                     159.0
# 2                                     288.2
# 3                                     312.7
# 4                                     337.7
#
#    Other_Professional_Services_Billions  Dental_Services_Billions  \
# 0                                   3.5                      13.3
# 1                                  17.3                      31.6
# 2                                  36.6                      62.1
# 3                                  40.3                      67.7
# 4                                  43.3                      73.6
#
#    Other_Health_Residential_and_Personal_Care_Billions  ...  \
# 0                                                8.4    ...
# 1                                               23.8    ...
# 2                                               63.5    ...
# 3                                               69.5    ...
# 4                                               76.0    ...
#
#    Retail_Outlet_Sales_of_Medical_Products_Billions  \
# 0                                              23.2
# 1                                              72.5
# 2                                             173.2
# 3                                             192.0
# 4                                             217.4
#
#    Prescription_Drugs_Billions  Durable_Medical_Equipment_Billions  \
# 0                         12.0                                 4.1
# 1                         40.3                                13.8
# 2                        122.0                                26.0
# 3                        140.6                                25.3
# 4                        159.8                                29.6
#
#    Other_Non-Durable_Medical_Products_Billions  \
# 0                                          7.1
# 1                                         18.5
# 2                                         25.2
# 3                                         26.1
# 4                                         27.9
#
#    Government_Administration_Billions  Net_Cost_of_Health_Insurance_Billions  \
# 0                                 2.8                                    9.1
# 1                                 7.2                                   31.1
# 2                                17.2                                   63.6
# 3                                19.7                                   70.4
# 4                                22.7                                   89.1
#
#    Government_Public_Health_Activities_Billions  Investment_Billions  \
# 0                                           6.4                 20.6
# 1                                          20.0                 48.6
# 2                                          43.0                 85.7
# 3                                          46.8                 90.0
# 4                                          52.2                101.5
#
#    Research_Billions  Structures_and_Equipment_Billions
# 0                5.4                               15.1
# 1               12.7                               35.9
# 2               25.5                               60.2
# 3               28.5                               61.5
# 4               32.0                               69.4
#
# [5 rows x 22 columns]
#
# Data from nhe23-tables/new table 3 source of funds.xlsx:
#    Year  National_Health_Expenditures_Billions  \
# 0  1980                                  253.2
# 1  1990                                  718.7
# 2  2000                                 1366.0
# 3  2001                                 1483.4
# 4  2002                                 1631.0
#
#    Health_Consumption_Expenditures_Billions  Out_of_pocket_Billions  \
# 0                                     232.7                    55.3
# 1                                     670.2                   133.8
# 2                                    1280.3                   193.6
# 3                                    1393.4                   200.9
# 4                                    1529.6                   219.1
#
#    Health_Insurance_Billions  Private_Health_Insurance_Billions  \
# 0                      140.2                               67.1
# 1                      431.1                              225.9
# 2                      902.0                              441.0
# 3                      995.9                              483.4
# 4                     1098.1                              537.5
#
#    Medicare_Billions  Medicaid_Billions  Federal _Billions  \
# 0               37.4               26.0               14.5
# 1              110.2               73.7               42.6
# 2              224.8              200.4              116.8
# 3              247.7              224.1              132.2
# 4              265.4              248.1              145.3
#
#    State_and_Local_Billions  Other_Health_Insurance_Programs_Billions  \
# 0                      11.5                                       9.7
# 1                      31.1                                      21.4
# 2                      83.5                                      35.8
# 3                      91.9                                      40.7
# 4                     102.8                                      47.1
#
#    Other_Third_Party_Payers_and_Programs_and_Public_Health_Activity_Billions  \
# 0                                               37.2
# 1                                              105.3
# 2                                              184.8
# 3                                              196.7
# 4                                              212.3
#
#    Investment_Billions
# 0                 20.6
# 1                 48.6
# 2                 85.7
# 3                 90.0
# 4                101.5
#
# Data from nhe23-tables/new table 5 type of sponsors.xlsx:
#    Year  National_Health_Expenditures_Billions  \
# 0  1987                                  514.5
# 1  1988                                  576.6
# 2  1989                                  642.2
# 3  1990                                  718.7
# 4  1991                                  786.0
#
#    Business_Households_and_Other_Private_Billions  Private_Business_Billions  \
# 0                                           349.8                      119.5
# 1                                           397.5                      135.4
# 2                                           440.0                      154.7
# 3                                           483.8                      173.3
# 4                                           517.5                      187.0
#
#    Household_Billions  Other_Private_Revenues_Billions  Government_Billions  \
# 0               189.3                             41.0                164.7
# 1               213.9                             48.2                179.2
# 2               233.7                             51.7                202.2
# 3               254.2                             56.3                234.9
# 4               270.3                             60.2                268.5
#
#    Federal_Billions  State_and_Local_Billions
# 0              86.4                      78.4
# 1              92.5                      86.7
# 2             105.5                      96.6
# 3             125.3                     109.7
# 4             146.6                     121.9

# %%
# 1. Display basic .info() to see data types and non-null counts
print("=== CSV Data Info ===")
csv_data.info()
print("\n")

for file_path, df in excel_data.items():
    print(f"=== Excel Data Info: {file_path} ===")
    df.info()
    print("\n")
# Out:
# === CSV Data Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4580 entries, 0 to 4579
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   measure_name  4580 non-null   object
#  1   cause_id      4580 non-null   int64
#  2   cause_name    4580 non-null   object
#  3   metric_name   4580 non-null   object
#  4   year          4580 non-null   int64
#  5   val           4580 non-null   float64
#  6   upper         4580 non-null   float64
#  7   lower         4580 non-null   float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 286.4+ KB
#
#
# === Excel Data Info: nhe23-tables/new table 1 total expenditures.xlsx ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Year                                                                 26 non-null     int64
#  1   Nationa_Health_Expenditures _Billions                                26 non-null     float64
#  2   Health_Consumption_Expenditures_Billions                             26 non-null     float64
#  3   Personal_Health_Care_Billions                                        26 non-null     float64
#  4   Government_Administration_and_Net_Cost_of_Health_Insurance_Billions  26 non-null     float64
#  5   Government_Public_Health_Activities_Billions                         26 non-null     float64
#  6    Investment_Billions                                                 26 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 1.6 KB
#
#
# === Excel Data Info: nhe23-tables/new table 2 expenditures total amount.xlsx ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 22 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Year                                                                        26 non-null     int64
#  1   National_Health_Expenditures_Billions                                       26 non-null     float64
#  2   Health_Consumption_Expenditures_Billions                                    26 non-null     float64
#  3   Personal_Health_Care_Billlions                                              26 non-null     float64
#  4   Hospital_Care_Billions                                                      26 non-null     float64
#  5   Professional_Services_Billions                                              26 non-null     float64
#  6   Physician_and_Clinical_Services_Billions                                    26 non-null     float64
#  7   Other_Professional_Services_Billions                                        26 non-null     float64
#  8   Dental_Services_Billions                                                    26 non-null     float64
#  9   Other_Health_Residential_and_Personal_Care_Billions                         26 non-null     float64
#  10  Home_Health_Care_Billions                                                   26 non-null     float64
#  11  Nursin_Care_Facilities_and_Continuing_Care_Retirement_Communities_Billions  26 non-null     float64
#  12  Retail_Outlet_Sales_of_Medical_Products_Billions                            26 non-null     float64
#  13  Prescription_Drugs_Billions                                                 26 non-null     float64
#  14  Durable_Medical_Equipment_Billions                                          26 non-null     float64
#  15  Other_Non-Durable_Medical_Products_Billions                                 26 non-null     float64
#  16  Government_Administration_Billions                                          26 non-null     float64
#  17  Net_Cost_of_Health_Insurance_Billions                                       26 non-null     float64
#  18  Government_Public_Health_Activities_Billions                                26 non-null     float64
#  19  Investment_Billions                                                         26 non-null     float64
#  20  Research_Billions                                                           26 non-null     float64
#  21  Structures_and_Equipment_Billions                                           26 non-null     float64
# dtypes: float64(21), int64(1)
# memory usage: 4.6 KB
#
#
# === Excel Data Info: nhe23-tables/new table 3 source of funds.xlsx ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 13 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   Year                                                                       26 non-null     int64
#  1   National_Health_Expenditures_Billions                                      26 non-null     float64
#  2   Health_Consumption_Expenditures_Billions                                   26 non-null     float64
#  3   Out_of_pocket_Billions                                                     26 non-null     float64
#  4   Health_Insurance_Billions                                                  26 non-null     float64
#  5   Private_Health_Insurance_Billions                                          26 non-null     float64
#  6   Medicare_Billions                                                          26 non-null     float64
#  7   Medicaid_Billions                                                          26 non-null     float64
#  8   Federal _Billions                                                          26 non-null     float64
#  9   State_and_Local_Billions                                                   26 non-null     float64
#  10  Other_Health_Insurance_Programs_Billions                                   26 non-null     float64
#  11  Other_Third_Party_Payers_and_Programs_and_Public_Health_Activity_Billions  26 non-null     float64
#  12  Investment_Billions                                                        26 non-null     float64
# dtypes: float64(12), int64(1)
# memory usage: 2.8 KB
#
#
# === Excel Data Info: nhe23-tables/new table 5 type of sponsors.xlsx ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 9 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Year                                            37 non-null     int64
#  1   National_Health_Expenditures_Billions           37 non-null     float64
#  2   Business_Households_and_Other_Private_Billions  37 non-null     float64
#  3   Private_Business_Billions                       37 non-null     float64
#  4   Household_Billions                              37 non-null     float64
#  5   Other_Private_Revenues_Billions                 37 non-null     float64
#  6   Government_Billions                             37 non-null     float64
#  7   Federal_Billions                                37 non-null     float64
#  8   State_and_Local_Billions                        37 non-null     float64
# dtypes: float64(8), int64(1)
# memory usage: 2.7 KB

# %%
# 2. Display descriptive statistics for numeric columns
print("=== CSV Data Descriptive Statistics ===")
print(csv_data.describe(include=[float, int]))  # numeric columns only

for file_path, df in excel_data.items():
    print(f"\n=== Descriptive Statistics for {file_path} ===")
    print(df.describe(include=[float, int]))
# Out:
# === CSV Data Descriptive Statistics ===
#           cause_id         year           val         upper         lower
# count  4580.000000  4580.000000  4.580000e+03  4.580000e+03  4.580000e+03
# mean    690.940611  2003.574236  8.118298e+06  8.709065e+06  7.578482e+06
# std     210.702532    10.721308  2.488846e+07  2.626734e+07  2.359771e+07
# min     344.000000  1980.000000  7.485876e-03  8.204955e-03  6.429153e-03
# 25%     526.000000  1995.000000  3.810808e+02  3.982292e+02  3.464801e+02
# 50%     653.000000  2004.000000  1.467153e+04  1.517467e+04  1.391989e+04
# 75%     956.000000  2013.000000  1.535329e+06  1.715447e+06  1.349377e+06
# max     974.000000  2021.000000  2.096131e+08  2.164140e+08  2.026021e+08
#
# === Descriptive Statistics for nhe23-tables/new table 1 total expenditures.xlsx ===
#               Year  Nationa_Health_Expenditures _Billions  \
# count    26.000000                              26.000000
# mean   2009.461538                            2676.026923
# std       9.992921                            1146.355871
# min    1980.000000                             253.200000
# 25%    2004.250000                            1927.675000
# 50%    2010.500000                            2633.050000
# 75%    2016.750000                            3411.775000
# max    2023.000000                            4866.500000
#
#        Health_Consumption_Expenditures_Billions  \
# count                                 26.000000
# mean                                2527.200000
# std                                 1094.914955
# min                                  232.700000
# 25%                                 1808.600000
# 50%                                 2477.650000
# 75%                                 3232.050000
# max                                 4627.700000
#
#        Personal_Health_Care_Billions  \
# count                      26.000000
# mean                     2241.511538
# std                       953.331464
# min                       214.300000
# 25%                      1610.250000
# 50%                      2217.200000
# 75%                      2874.425000
# max                      4107.400000
#
#        Government_Administration_and_Net_Cost_of_Health_Insurance_Billions  \
# count                                          26.000000
# mean                                          197.311538
# std                                            92.908322
# min                                            11.900000
# 25%                                           142.800000
# 50%                                           185.450000
# 75%                                           263.675000
# max                                           360.200000
#
#        Government_Public_Health_Activities_Billions   Investment_Billions
# count                                     26.000000             26.000000
# mean                                      88.392308            148.834615
# std                                       56.621946             52.244854
# min                                        6.400000             20.600000
# 25%                                       55.500000            119.050000
# 50%                                       75.050000            157.500000
# 75%                                       94.025000            179.725000
# max                                      240.800000            238.800000
#
# === Descriptive Statistics for nhe23-tables/new table 2 expenditures total amount.xlsx ===
#               Year  National_Health_Expenditures_Billions  \
# count    26.000000                              26.000000
# mean   2009.461538                            2676.026923
# std       9.992921                            1146.355871
# min    1980.000000                             253.200000
# 25%    2004.250000                            1927.675000
# 50%    2010.500000                            2633.050000
# 75%    2016.750000                            3411.775000
# max    2023.000000                            4866.500000
#
#        Health_Consumption_Expenditures_Billions  \
# count                                 26.000000
# mean                                2527.200000
# std                                 1094.914955
# min                                  232.700000
# 25%                                 1808.600000
# 50%                                 2477.650000
# 75%                                 3232.050000
# max                                 4627.700000
#
#        Personal_Health_Care_Billlions  Hospital_Care_Billions  \
# count                       26.000000               26.000000
# mean                      2241.511538              827.742308
# std                        953.331464              355.978132
# min                        214.300000              100.500000
# 25%                       1610.250000              576.125000
# 50%                       2217.200000              821.000000
# 75%                       2874.425000             1067.050000
# max                       4107.400000             1519.700000
#
#        Professional_Services_Billions  \
# count                       26.000000
# mean                       721.084615
# std                        303.835042
# min                         64.500000
# 25%                        525.200000
# 50%                        702.350000
# 75%                        926.900000
# max                       1311.700000
#
#        Physician_and_Clinical_Services_Billions  \
# count                                 26.000000
# mean                                 540.215385
# std                                  228.462168
# min                                   47.700000
# 25%                                  390.900000
# 50%                                  524.100000
# 75%                                  701.250000
# max                                  978.000000
#
#        Other_Professional_Services_Billions  Dental_Services_Billions  \
# count                             26.000000                 26.000000
# mean                              75.526923                105.342308
# std                               37.513641                 38.394553
# min                                3.500000                 13.300000
# 25%                               50.850000                 83.450000
# 50%                               71.350000                106.950000
# 75%                               95.700000                129.875000
# max                              159.900000                173.800000
#
#        Other_Health_Residential_and_Personal_Care_Billions  ...  \
# count                                          26.000000    ...
# mean                                          134.638462    ...
# std                                            65.517174    ...
# min                                             8.400000    ...
# 25%                                            90.200000    ...
# 50%                                           129.050000    ...
# 75%                                           181.550000    ...
# max                                           270.200000    ...
#
#        Retail_Outlet_Sales_of_Medical_Products_Billions  \
# count                                         26.000000
# mean                                         350.211538
# std                                          147.068042
# min                                           23.200000
# 25%                                          266.275000
# 50%                                          349.300000
# 75%                                          437.950000
# max                                          646.700000
#
#        Prescription_Drugs_Billions  Durable_Medical_Equipment_Billions  \
# count                    26.000000                           26.000000
# mean                    250.815385                           41.607692
# std                     102.648553                           15.127589
# min                      12.000000                            4.100000
# 25%                     198.850000                           33.950000
# 50%                     255.300000                           42.950000
# 75%                     315.100000                           47.300000
# max                     449.700000                           72.800000
#
#        Other_Non-Durable_Medical_Products_Billions  \
# count                                    26.000000
# mean                                     57.788462
# std                                      30.642994
# min                                       7.100000
# 25%                                      33.400000
# 50%                                      54.200000
# 75%                                      75.550000
# max                                     124.100000
#
#        Government_Administration_Billions  \
# count                           26.000000
# mean                            33.873077
# std                             13.723981
# min                              2.800000
# 25%                             27.575000
# 50%                             31.650000
# 75%                             44.100000
# max                             57.400000
#
#        Net_Cost_of_Health_Insurance_Billions  \
# count                              26.000000
# mean                              163.442308
# std                                79.396071
# min                                 9.100000
# 25%                               115.200000
# 50%                               153.800000
# 75%                               219.575000
# max                               302.900000
#
#        Government_Public_Health_Activities_Billions  Investment_Billions  \
# count                                     26.000000            26.000000
# mean                                      88.392308           148.834615
# std                                       56.621946            52.244854
# min                                        6.400000            20.600000
# 25%                                       55.500000           119.050000
# 50%                                       75.050000           157.500000
# 75%                                       94.025000           179.725000
# max                                      240.800000           238.800000
#
#        Research_Billions  Structures_and_Equipment_Billions
# count          26.000000                          26.000000
# mean           44.192308                         104.630769
# std            15.116823                          37.362235
# min             5.400000                          15.100000
# 25%            39.025000                          80.100000
# 50%            46.200000                         110.600000
# 75%            50.575000                         129.650000
# max            72.100000                         166.600000
#
# [8 rows x 22 columns]
#
# === Descriptive Statistics for nhe23-tables/new table 3 source of funds.xlsx ===
#               Year  National_Health_Expenditures_Billions  \
# count    26.000000                              26.000000
# mean   2009.461538                            2676.026923
# std       9.992921                            1146.355871
# min    1980.000000                             253.200000
# 25%    2004.250000                            1927.675000
# 50%    2010.500000                            2633.050000
# 75%    2016.750000                            3411.775000
# max    2023.000000                            4866.500000
#
#        Health_Consumption_Expenditures_Billions  Out_of_pocket_Billions  \
# count                                 26.000000                26.00000
# mean                                2527.200000               308.40000
# std                                 1094.914955               101.27684
# min                                  232.700000                55.30000
# 25%                                 1808.600000               252.42500
# 50%                                 2477.650000               305.85000
# 75%                                 3232.050000               368.95000
# max                                 4627.700000               505.70000
#
#        Health_Insurance_Billions  Private_Health_Insurance_Billions  \
# count                  26.000000                          26.000000
# mean                 1882.592308                         827.980769
# std                   845.215390                         327.444305
# min                   140.200000                          67.100000
# 25%                  1312.025000                         637.350000
# 50%                  1867.500000                         835.600000
# 75%                  2468.675000                        1065.425000
# max                  3558.600000                        1464.600000
#
#        Medicare_Billions  Medicaid_Billions  Federal _Billions  \
# count          26.000000          26.000000          26.000000
# mean          529.111538         428.800000         271.196154
# std           260.399521         212.248289         150.270507
# min            37.400000          26.000000          14.500000
# 25%           318.275000         294.700000         172.700000
# 50%           532.050000         402.050000         247.400000
# 75%           697.725000         575.100000         360.500000
# max          1029.800000         871.700000         591.400000
#
#        State_and_Local_Billions  Other_Health_Insurance_Programs_Billions  \
# count                 26.000000                                 26.000000
# mean                 157.592308                                 96.719231
# std                   65.027729                                 48.352903
# min                   11.500000                                  9.700000
# 25%                  120.600000                                 60.975000
# 50%                  150.350000                                 97.850000
# 75%                  210.525000                                130.425000
# max                  280.300000                                192.500000
#
#        Other_Third_Party_Payers_and_Programs_and_Public_Health_Activity_Billions  \
# count                                          26.000000
# mean                                          336.207692
# std                                           159.594446
# min                                            37.200000
# 25%                                           244.175000
# 50%                                           304.300000
# 75%                                           394.425000
# max                                           743.900000
#
#        Investment_Billions
# count            26.000000
# mean            148.834615
# std              52.244854
# min              20.600000
# 25%             119.050000
# 50%             157.500000
# 75%             179.725000
# max             238.800000
#
# === Descriptive Statistics for nhe23-tables/new table 5 type of sponsors.xlsx ===
#               Year  National_Health_Expenditures_Billions  \
# count    37.000000                              37.000000
# mean   2005.000000                            2169.586486
# std      10.824355                            1241.351248
# min    1987.000000                             514.500000
# 25%    1996.000000                            1073.600000
# 50%    2005.000000                            2026.600000
# 75%    2014.000000                            3002.100000
# max    2023.000000                            4866.500000
#
#        Business_Households_and_Other_Private_Billions  \
# count                                       37.000000
# mean                                      1228.470270
# std                                        608.840028
# min                                        349.800000
# 25%                                        669.300000
# 50%                                       1223.400000
# 75%                                       1642.000000
# max                                       2539.000000
#
#        Private_Business_Billions  Household_Billions  \
# count                  37.000000           37.000000
# mean                  441.527027          634.008108
# std                   207.851028          320.579660
# min                   119.500000          189.300000
# 25%                   252.900000          332.700000
# 50%                   469.800000          616.300000
# 75%                   579.300000          856.800000
# max                   894.000000         1316.600000
#
#        Other_Private_Revenues_Billions  Government_Billions  Federal_Billions  \
# count                        37.000000            37.000000         37.000000
# mean                        152.951351           941.118919        587.610811
# std                          81.540980           636.361600        444.176573
# min                          41.000000           164.700000         86.400000
# 25%                          83.700000           404.300000        232.100000
# 50%                         137.300000           803.200000        456.500000
# 75%                         205.900000          1360.100000        842.900000
# max                         328.400000          2327.500000       1566.200000
#
#        State_and_Local_Billions
# count                 37.000000
# mean                 353.502703
# std                  196.934256
# min                   78.400000
# 25%                  172.200000
# 50%                  346.700000
# 75%                  517.200000
# max                  761.300000

# %% [markdown]
# #### Overall Observations
#
# - The dataset is wide-ranging: it covers multiple diseases (cause IDs), a 1980–2021 time frame, and drastically varying magnitudes of val (from near zero to over 200 million).
# - The difference between 25th percentile (381) and 75th percentile (1.53 × 10^6) for val underscores a heavily skewed distribution, likely dominated by a few extremely high-burden causes/years.

# %% [markdown]
# #### Overall Insights & Relevance to Research Questions
#
# 1. **Time Coverage**
#    - **NHE Tables 1, 2, 3** each contain 26 rows, covering roughly **1980–2023**, while **Table 5** has 37 rows (1987–2023).
#    - This indicates partial coverage: you may have fewer overlapping years when merging with IHME data (which spans 1980–2021).
#
# 2. **Expenditure Growth**
#    - Across all tables, total health expenditures have **increased substantially** over time, from as low as \$253.2 billion (1980) to nearly \$4.9 trillion (2023).
#    - Subcategories (e.g., hospital care, physician services, prescription drugs) and sources of funds (Medicare, Medicaid, private) also show significant growth patterns.
#
# 3. **Type of Sponsor** (Table 5)
#    - Shows how **government vs. private** sponsorship has evolved, which could be relevant if you’re exploring whether **financing mechanisms** correlate with disease outcomes.
#
# 4. **Potential for Correlation**
#    - Given the **rising expenditures** in different categories, you can investigate if **increases** in specific spending types (e.g., hospital care) are linked to **reduced mortality** in particular diseases (from IHME).
#
# 5. **Data Quality**
#    - All tables show **no missing values** in their numeric columns, simplifying merges and subsequent analysis.
#
# 6. **Relevance to Research Questions**
#    - **Question 1** (Overall spending vs. mortality):
#      - Tables 1 and 2 (which detail total and category-level spending) can be merged with IHME data on `year` to see if higher total spending aligns with changes in overall mortality or disease rates.
#    - **Question 2** (Impact of different expenditure types on specific diseases):
#      - The **breakdowns** in Table 2 (type of service), Table 3 (source of funds), and Table 5 (sponsor type) allow a deeper dive into which expenditures might correlate most strongly with certain diseases in IHME.

# %%
import seaborn as sns

# %% [markdown]
# Since each row in our tables represents a single year and we only have one data point per year for each expenditure or disease metric, a histogram or box plot can still show basic distribution and detect outliers—but we’ll have very few data points (e.g., 26 or 37). In that case, it’s often more insightful to treat these variables as time series and use line plots or time-series methods (e.g., trend analysis, correlation over time) to see how they evolve year by year.

# %%
df_table1 = pd.read_excel("nhe23-tables/new table 1 total expenditures.xlsx")

# Sort by Year just in case
df_table1 = df_table1.sort_values("Year")

# Pick a column to plot, e.g. 'Nationa_Health_Expenditures _Billions'
plt.figure(figsize=(8,5))
plt.plot(df_table1["Year"], df_table1["Nationa_Health_Expenditures _Billions"], marker='o')
plt.title("National Health Expenditures Over Time (Table 1)")
plt.xlabel("Year")
plt.ylabel("Expenditures (Billions)")
plt.grid(True)
plt.show()

# %%
real_dollars_df = pd.read_csv('nhe23-tables/new book 23 real dollars 2017.csv')
real_dollars_df = real_dollars_df.sort_values("Year")

plt.figure(figsize=(8,5))
plt.plot(real_dollars_df["Year"], real_dollars_df["National_Health_Expenditures_Billions"], marker='o')
plt.title("National Health Expenditures Over Time (Real Dollars)")
plt.xlabel("Year")
plt.ylabel("Expenditures (Billions)")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Comparison of Nominal vs. Real Dollar Expenditures
#
# From the two plots:
#
# 1. **Nominal Expenditures (Table 1)**
#    - Shows a **steady upward trend** from roughly \$253.2 billion in **1980** to almost **\$5 trillion** by **2023**.
#    - The growth appears **smooth** and fairly **consistent** across the years, reflecting **both** true increases in health spending and **inflation** over time.
#
# 2. **Real Dollar Expenditures**
#    - Adjusted for inflation (e.g., to a constant year’s value).
#    - Remains **relatively flat** until around **2000**, then **accelerates sharply** in the 2000s and 2010s, reaching around **\$4.2 trillion** in 2023.
#    - This indicates that **even in constant dollars**, health expenditures have **increased significantly** since the early 2000s—just not as steadily as the nominal curve suggests.
#
# ### Key Observations
#
# - **Inflation Effect**:
#   - The nominal plot rises more **gradually** (due to compounding inflation), whereas the real-dollar plot remains **lower** and more **compressed** in earlier decades, then **surges** later.
#   - This highlights how **inflation** can mask or exaggerate certain spending patterns when looking at raw dollars over multiple decades.
#
# - **Implications for Analysis**:
#   - Using **nominal** dollars can overstate growth caused by **price inflation** rather than actual increases in **resource allocation**.
#   - **Real** dollars provide a **truer** sense of how much more (or less) healthcare resources are consumed over time.
#
# - **Relevance to Research Questions**:
#   1. **Overall Spending vs. Mortality (Q1)**:
#      - Analyzing **real** expenditures might give a clearer picture of whether true resource increases correlate with changes in mortality.
#   2. **Subcategories and Specific Diseases (Q2)**:
#      - When comparing different spending types (e.g., hospital care, prescription drugs) to disease outcomes, using **real dollars** ensures a **fair comparison** across years.
#
# In summary, **both** plots confirm the **major growth** in U.S. health expenditures, but the **real-dollar** plot is often more **reliable** for long-term trend analysis, avoiding the confounding effects of inflation.

# %%
print(real_dollars_df.columns)
print(csv_data.columns)
# Out:
# Index(['Year', 'National_Health_Expenditures_Billions',
#        'Personal_Health_Care_Billions', 'Hospital_Care_Billions',
#        'Physician_and_Clinical_Services_Billions',
#        'Other_Professional_Services_Billions', 'Dental_Services_Billions',
#        'Other_Health_Residential_and_Personal_Care_Billions',
#        'Home_Health_Care_Billions',
#        'Nursing_Home_Facilities_and_Continuing_Care_Retirement_Communities_Billions',
#        'Prescription_Drugs_Billions',
#        'Other_Non-Durable_Medical_Products_Billions',
#        'Durable_Medical_Equipment_Billions',
#        'Government_Administration_Billions',
#        'Net_Cost_of_Health_Insurance_Billions',
#        'Government_Public_Health_Actitives_Billions', 'Research_Billions',
#        'Structures_and_Equipment_Billions'],
#       dtype='object')
# Index(['measure_name', 'cause_id', 'cause_name', 'metric_name', 'year', 'val',
#        'upper', 'lower'],
#       dtype='object')

# %%
real_dollars_df['year'] = real_dollars_df['Year']
real_dollars_df = real_dollars_df.drop(columns=['Year'])
print(real_dollars_df.columns)
# Out:
# Index(['National_Health_Expenditures_Billions',
#        'Personal_Health_Care_Billions', 'Hospital_Care_Billions',
#        'Physician_and_Clinical_Services_Billions',
#        'Other_Professional_Services_Billions', 'Dental_Services_Billions',
#        'Other_Health_Residential_and_Personal_Care_Billions',
#        'Home_Health_Care_Billions',
#        'Nursing_Home_Facilities_and_Continuing_Care_Retirement_Communities_Billions',
#        'Prescription_Drugs_Billions',
#        'Other_Non-Durable_Medical_Products_Billions',
#        'Durable_Medical_Equipment_Billions',
#        'Government_Administration_Billions',
#        'Net_Cost_of_Health_Insurance_Billions',
#        'Government_Public_Health_Actitives_Billions', 'Research_Billions',
#        'Structures_and_Equipment_Billions', 'year'],
#       dtype='object')

# %%
# Filter for measure_name == "Deaths"
deaths_df = csv_data[csv_data["measure_name"] == "Deaths"].copy()

# %%
total_deaths_per_year = deaths_df.groupby("year", as_index=False)["val"].sum()
total_deaths_per_year.rename(columns={"val": "Total_Deaths"}, inplace=True)

# %%
import matplotlib.ticker as mtick

# %%
final_df = pd.merge(real_dollars_df, total_deaths_per_year, on="year", how="inner")

fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(
    final_df["National_Health_Expenditures_Billions"],
    final_df["Total_Deaths"]
)
ax.set_title("Real Health Expenditures vs. Total Deaths")
ax.set_xlabel("National Health Expenditures (Real Billions)")
ax.set_ylabel("Total Deaths")

# use a StrMethodFormatter for thousands separators or currency
formatter = mtick.StrMethodFormatter('{x:,.0f}')  # e.g., "3,500"
ax.xaxis.set_major_formatter(formatter)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observations: Real Health Expenditures vs. Total Deaths
#
# 1. **Positive Relationship**
#    - As real health expenditures increase (x-axis), total deaths (y-axis) also rise, suggesting a **positive correlation** in this dataset.
#    - The scatter points form a generally **upward-sloping** trend, indicating that years with higher spending also have higher total deaths.
#
# 2. **Axis Scaling**
#    - The x-axis ranges from **0 to ~12**—likely reflecting **trillions** of real dollars in a simplified scale or a transformed unit.
#    - The y-axis spans roughly **2.0×10^6** to **3.4×10^6** total deaths, showing an increase of around **1.4 million** deaths across the plotted time frame.
#
# 3. **Possible Explanations**
#    - **Population Growth**: As the U.S. population grows, both total spending and total deaths can rise in tandem.
#    - **Aging Demographics**: An older population often leads to higher death counts and increased healthcare spending.
#    - **Inflation Adjustment**: These expenditures are in **real (inflation-adjusted)** dollars, so the growth represents true increases in resource allocation rather than just price inflation.
#
# 4. **Limitations & Next Steps**
#    - **Correlation ≠ Causation**: A higher spending year does not necessarily *cause* more deaths. External factors (e.g., population size, disease prevalence) likely drive both spending and mortality trends.
#    - **Normalized Measures**: You might consider **per capita** expenditures or **age-standardized** mortality rates for a clearer insight into how spending tracks with health outcomes independent of population changes.
#    - **Subcategory Analysis**: If **Question 2** involves specific expenditure types (e.g., hospital care, prescription drugs), plotting them individually against cause-specific mortality may offer deeper insight.
#
# Overall, this plot confirms a **positive association** between real health expenditures and total deaths over time, highlighting the complexity of interpreting healthcare spending trends alongside mortality.

# %%
print(final_df.columns)
# Out:
# Index(['National_Health_Expenditures_Billions',
#        'Personal_Health_Care_Billions', 'Hospital_Care_Billions',
#        'Physician_and_Clinical_Services_Billions',
#        'Other_Professional_Services_Billions', 'Dental_Services_Billions',
#        'Other_Health_Residential_and_Personal_Care_Billions',
#        'Home_Health_Care_Billions',
#        'Nursing_Home_Facilities_and_Continuing_Care_Retirement_Communities_Billions',
#        'Prescription_Drugs_Billions',
#        'Other_Non-Durable_Medical_Products_Billions',
#        'Durable_Medical_Equipment_Billions',
#        'Government_Administration_Billions',
#        'Net_Cost_of_Health_Insurance_Billions',
#        'Government_Public_Health_Actitives_Billions', 'Research_Billions',
#        'Structures_and_Equipment_Billions', 'year', 'Total_Deaths'],
#       dtype='object')

# %%
subcategory_cols = [col for col in final_df.columns if col.endswith("_Billions")]
print(subcategory_cols)
# Out:
# ['National_Health_Expenditures_Billions', 'Personal_Health_Care_Billions', 'Hospital_Care_Billions', 'Physician_and_Clinical_Services_Billions', 'Other_Professional_Services_Billions', 'Dental_Services_Billions', 'Other_Health_Residential_and_Personal_Care_Billions', 'Home_Health_Care_Billions', 'Nursing_Home_Facilities_and_Continuing_Care_Retirement_Communities_Billions', 'Prescription_Drugs_Billions', 'Other_Non-Durable_Medical_Products_Billions', 'Durable_Medical_Equipment_Billions', 'Government_Administration_Billions', 'Net_Cost_of_Health_Insurance_Billions', 'Government_Public_Health_Actitives_Billions', 'Research_Billions', 'Structures_and_Equipment_Billions']

# %%
print(final_df[subcategory_cols].dtypes)
# Out:
# National_Health_Expenditures_Billions                                           object
# Personal_Health_Care_Billions                                                   object
# Hospital_Care_Billions                                                          object
# Physician_and_Clinical_Services_Billions                                       float64
# Other_Professional_Services_Billions                                           float64
# Dental_Services_Billions                                                       float64
# Other_Health_Residential_and_Personal_Care_Billions                            float64
# Home_Health_Care_Billions                                                      float64
# Nursing_Home_Facilities_and_Continuing_Care_Retirement_Communities_Billions    float64
# Prescription_Drugs_Billions                                                    float64
# Other_Non-Durable_Medical_Products_Billions                                    float64
# Durable_Medical_Equipment_Billions                                             float64
# Government_Administration_Billions                                              object
# Net_Cost_of_Health_Insurance_Billions                                           object
# Government_Public_Health_Actitives_Billions                                     object
# Research_Billions                                                               object
# Structures_and_Equipment_Billions                                               object
# dtype: object

# %%
object_cols = [
    "Personal_Health_Care_Billions", 
    "Hospital_Care_Billions",
    "National_Health_Expenditures_Billions",
    "Government_Administration_Billions",
    "Net_Cost_of_Health_Insurance_Billions",
    "Government_Public_Health_Actitives_Billions",
    "Research_Billions",
    "Structures_and_Equipment_Billions"
]

for col in object_cols:
    final_df[col] = pd.to_numeric(final_df[col], errors="coerce")

# %%
print(final_df[subcategory_cols].dtypes)
# Out:
# National_Health_Expenditures_Billions                                          float64
# Personal_Health_Care_Billions                                                  float64
# Hospital_Care_Billions                                                         float64
# Physician_and_Clinical_Services_Billions                                       float64
# Other_Professional_Services_Billions                                           float64
# Dental_Services_Billions                                                       float64
# Other_Health_Residential_and_Personal_Care_Billions                            float64
# Home_Health_Care_Billions                                                      float64
# Nursing_Home_Facilities_and_Continuing_Care_Retirement_Communities_Billions    float64
# Prescription_Drugs_Billions                                                    float64
# Other_Non-Durable_Medical_Products_Billions                                    float64
# Durable_Medical_Equipment_Billions                                             float64
# Government_Administration_Billions                                             float64
# Net_Cost_of_Health_Insurance_Billions                                          float64
# Government_Public_Health_Actitives_Billions                                    float64
# Research_Billions                                                              float64
# Structures_and_Equipment_Billions                                              float64
# dtype: object

# %%
# Filter out the total
subcategory_cols = [col for col in subcategory_cols if col not in ["National_Health_Expenditures_Billions", "Personal_Health_Care_Billions"]]

# %%
# Calculate the final (or average) value for each subcategory
final_values = []
for col in subcategory_cols:
    val = final_df[col].iloc[-1]  # or .mean() for average
    final_values.append((col, val))

# 3. Sort by descending value and pick top 5
final_values.sort(key=lambda x: x[1], reverse=True)
top_5 = [item[0] for item in final_values[:5]]

# 4. Plot only those top 5
plt.figure(figsize=(8,5))
for col in top_5:
    plt.plot(final_df["year"], final_df[col], label=col)

plt.title("Top 5 Subcategory Spending Over Time")
plt.xlabel("Year")
plt.ylabel("Billions of Dollars (Real)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Top 5 Subcategory Spending Over Time (Real Dollars)
#
# 1. **Hospital Care**
#    - Shows a **steady and substantial increase** from below \$200 billion in the early 1980s to nearly **\$900+ billion** by the 2020s.
#    - This category remains the **largest** among the five subcategories, indicating a major driver of overall health spending growth.
#
# 2. **Physician and Clinical Services**
#    - Also rises consistently, but at a slightly lower absolute level than Hospital Care.
#    - By the mid-2010s, it exceeds **\$500–\$600 billion**, underscoring the continued importance of outpatient and physician-based services.
#
# 3. **Prescription Drugs**
#    - Experiences a **sharp incline** starting around the 1990s and continues upward.
#    - Not as high as hospital or physician spending, but still surpasses **\$300+ billion** by the 2020s, reflecting the **rapid expansion** in pharmaceutical use and costs.
#
# 4. **Net Cost of Health Insurance**
#    - Displays a notable climb over the same period, approaching **\$400+ billion** in recent years.
#    - Represents administrative costs and insurer margins, suggesting an increasing financial footprint for payers in the healthcare system.
#
# 5. **Other Health, Residential, and Personal Care**
#    - Grows steadily from **\$50–\$60 billion** in the 1980s to around **\$200–\$300 billion** by the 2020s.
#    - Covers a wide range of non-hospital, non-physician services (e.g., mental health facilities, long-term care beyond nursing homes), indicating ongoing diversification in healthcare spending.
#
# ### Key Observations
#
# - **Strong Upward Trends**: All five subcategories show **consistent growth** over time, albeit at different scales.
# - **Hospital Care Dominance**: Remains the largest single subcategory, but Physician Services and Insurance Costs have also become substantial.
# - **Prescription Drugs Spike**: Marked growth in the 1990s–2000s, aligning with the rise of new pharmaceuticals and expanded coverage.
# - **Insurance Administration**: The net cost of health insurance has become a **major** line item, reflecting the complexity of the U.S. financing model.
#
# Overall, these top subcategories illustrate the **multi-faceted** nature of healthcare spending growth—ranging from inpatient services to outpatient care, pharmaceuticals, and insurance overhead.

# %%
merged_df = pd.merge(
    csv_data,       # columns: measure_name, cause_name, cause_id, val, upper, lower, etc.
    final_df,        # columns: Hospital_Care_Billions, Prescription_Drugs_Billions, ...
    on="year",
    how="inner"      # or "left"/"outer" depending on your needs
)

# %%
print("Columns in merged_df:", merged_df.columns)
print("Number of rows:", len(merged_df))
print(merged_df.head())
# Out:
# Columns in merged_df: Index(['measure_name', 'cause_id', 'cause_name', 'metric_name', 'year', 'val',
#        'upper', 'lower', 'National_Health_Expenditures_Billions',
#        'Personal_Health_Care_Billions', 'Hospital_Care_Billions',
#        'Physician_and_Clinical_Services_Billions',
#        'Other_Professional_Services_Billions', 'Dental_Services_Billions',
#        'Other_Health_Residential_and_Personal_Care_Billions',
#        'Home_Health_Care_Billions',
#        'Nursing_Home_Facilities_and_Continuing_Care_Retirement_Communities_Billions',
#        'Prescription_Drugs_Billions',
#        'Other_Non-Durable_Medical_Products_Billions',
#        'Durable_Medical_Equipment_Billions',
#        'Government_Administration_Billions',
#        'Net_Cost_of_Health_Insurance_Billions',
#        'Government_Public_Health_Actitives_Billions', 'Research_Billions',
#        'Structures_and_Equipment_Billions', 'Total_Deaths'],
#       dtype='object')
# Number of rows: 1862
#   measure_name  cause_id                               cause_name metric_name  \
# 0       Deaths       410                                Neoplasms      Number
# 1       Deaths       410                                Neoplasms        Rate
# 2       Deaths       344  Neglected tropical diseases and malaria      Number
# 3       Deaths       344  Neglected tropical diseases and malaria        Rate
# 4       Deaths       626                Musculoskeletal disorders      Number
#
#    year            val          upper          lower  \
# 0  1980  451711.372800  463715.356900  429850.261000
# 1  1980     196.520742     201.743174     187.009885
# 2  1980     125.931132     136.190930     115.011189
# 3  1980       0.054787       0.059251       0.050037
# 4  1980    4875.554196    5017.673641    4627.440970
#
#    National_Health_Expenditures_Billions  Personal_Health_Care_Billions  ...  \
# 0                                    NaN                          852.0  ...
# 1                                    NaN                          852.0  ...
# 2                                    NaN                          852.0  ...
# 3                                    NaN                          852.0  ...
# 4                                    NaN                          852.0  ...
#
#    Nursing_Home_Facilities_and_Continuing_Care_Retirement_Communities_Billions  \
# 0                                               65.0
# 1                                               65.0
# 2                                               65.0
# 3                                               65.0
# 4                                               65.0
#
#    Prescription_Drugs_Billions  Other_Non-Durable_Medical_Products_Billions  \
# 0                         80.0                                         17.9
# 1                         80.0                                         17.9
# 2                         80.0                                         17.9
# 3                         80.0                                         17.9
# 4                         80.0                                         17.9
#
#    Durable_Medical_Equipment_Billions  Government_Administration_Billions  \
# 0                                10.3                                 NaN
# 1                                10.3                                 NaN
# 2                                10.3                                 NaN
# 3                                10.3                                 NaN
# 4                                10.3                                 NaN
#
#    Net_Cost_of_Health_Insurance_Billions  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Government_Public_Health_Actitives_Billions  Research_Billions  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
# 3                                          NaN                NaN
# 4                                          NaN                NaN
#
#    Structures_and_Equipment_Billions  Total_Deaths
# 0                                NaN  1.974293e+06
# 1                                NaN  1.974293e+06
# 2                                NaN  1.974293e+06
# 3                                NaN  1.974293e+06
# 4                                NaN  1.974293e+06
#
# [5 rows x 26 columns]

# %%
merged_deaths = merged_df[merged_df["measure_name"] == "Deaths"].copy()

# %%
merged_deaths_agg = (
    merged_deaths
    .groupby(["year", "cause_name"], as_index=False)["val"]
    .sum()
)

# %%
# 3. Get the unique cause_name values
all_diseases = merged_deaths["cause_name"].unique()

# 4. Loop over each disease
for disease in all_diseases:
    # a) Filter for the current disease
    df_disease = merged_deaths[merged_deaths["cause_name"] == disease].copy()
    
    # b) (Optional) Group by year if needed
    #    e.g., sum 'val' if you have multiple rows per year
    df_disease_year = df_disease.groupby("year", as_index=False)["val"].sum()
    df_disease_year.rename(columns={"val": "Deaths"}, inplace=True)
    
    # c) Merge with your NHE final_df on 'year'
    df_merged = pd.merge(df_disease_year, final_df, on="year", how="inner")
    
    # d) Plot an example: Disease Deaths vs. Year
    plt.figure(figsize=(8,5))
    plt.plot(df_merged["year"], df_merged["Deaths"], marker='o', label=f"{disease} Deaths")
    plt.title(f"{disease}: Deaths Over Time")
    plt.xlabel("Year")
    plt.ylabel("Deaths")
    plt.grid(True)
    plt.legend()
    plt.show()

# %% [markdown]
# ## Brief Summary of Disease-Specific Mortality Trends (1980–2020+)
#
# Below is a concise overview of the death trends for various diseases, grouped by **similar patterns**. These are **absolute death counts**, not rates, so population growth and demographic shifts can affect these numbers.
#
# ---
#
# ### 1. Diseases Showing Strong, Mostly Continuous Rise
#
# - **Neoplasms (Cancer)**
#   - ~450k in 1980 → 700k+ by 2020s
#   - Reflects an aging population and possibly lifestyle factors; improved treatments may moderate death *rates*.
#
# - **Diabetes & Kidney Diseases**
#   - ~60k in 1980 → 200k+ by 2020
#   - Significant increase in diabetes prevalence, possibly linked to obesity and other metabolic factors.
#
# - **Digestive Diseases**
#   - ~70k in 1980 → 130k+ by 2020
#   - Gradual climb, could be influenced by diet, alcohol use, or aging demographics.
#
# - **Neurological Disorders**
#   - ~100k in 1980 → 250k+ by 2020
#   - Includes Alzheimer’s and other dementias, which rise with longer life spans.
#
# - **Chronic Respiratory Diseases**
#   - ~70k → 220k+
#   - Long-term growth, often linked to smoking and air pollution.
#
# - **Substance Use Disorders**
#   - ~10k → 90k+
#   - Steep climb, may reflect opioid crises and broader substance issues in recent decades.
#
# - **Skin & Subcutaneous Diseases**
#   - ~2k → 7k+
#   - Smaller absolute numbers but a clear upward trend.
#
# ---
#
# ### 2. U-Shaped or “Down-Then-Up” Patterns
#
# - **Cardiovascular Diseases**
#   - ~920k in 1980, dips ~790k in early 2000s, then back to ~920k
#   - Initial improvements (better treatment/prevention) followed by a rebound, possibly due to obesity and other risk factors.
#
# - **Unintentional Injuries**
#   - ~50k in 1980 → 35k in 2000 → 80k by 2020
#   - Early decline suggests improved safety measures; recent surge might be linked to drug overdoses or other factors.
#
# - **Self-Harm & Interpersonal Violence**
#   - ~55k in 1980, dips ~50k by 2000, climbs ~70k, then slight drop
#   - Fluctuations may reflect social, economic, or policy changes around violence and suicide prevention.
#
# - **Transport Injuries**
#   - ~60k in 1980 → ~40k in ~2010 → ~45k+ by 2020
#   - Safety improvements initially reduced deaths; partial rebound in recent years.
#
# ---
#
# ### 3. Mostly Downward Trends
#
# - **Maternal & Neonatal Disorders**
#   - ~24k in 1980 → ~12k by 2020
#   - Suggests effective maternal health interventions.
#
# - **HIV/AIDS & STIs**
#   - Peaks ~25k in 1990, then a sharp decline to a few thousand by 2010s
#   - Reflects successful antiretroviral treatments and public health campaigns.
#
# ---
#
# ### 4. Complex or Fluctuating Patterns
#
# - **Neglected Tropical Diseases & Malaria**
#   - Mild dip in 1980s, rises post-2000 (~350+), slight plateau
#   - Possibly affected by funding changes, global eradication efforts, and data improvements.
#
# - **Respiratory Infections & Tuberculosis**
#   - Fairly stable until ~2010, then a huge spike (~500k)
#   - Could indicate new data/reporting changes or specific outbreaks.
#
# - **Enteric Infections**
#   - A few thousand in 1980, up to ~12k by 2010, mild decline afterward
#   - Reflects evolving sanitation, population growth, and possible outbreak cycles.
#
# - **Other Infectious Diseases**
#   - Dip in 1990s, resurgence post-2000 (6k+), partial leveling
#   - May reflect new emerging infections or improved reporting.
#
# - **Musculoskeletal Disorders**
#   - 5k in 1980 → 10k by 2000, then down to ~8k, slight rebound
#   - Possibly improved treatments, followed by demographic shifts (aging population).
#
# - **Mental Disorders**
#   - Very low absolute values (tens of deaths), big drop ~1990, then ~35–40 from 2005+
#   - Could be classification or reporting changes; typically not direct cause of death except in special cases.
#
# - **Nutritional Deficiencies**
#   - ~2k until ~2000, then jumps to ~12k by 2020
#   - Potentially a reflection of socio-economic factors or data changes in recent years.
#
# ---
#
# ### Overall Takeaways
#
# 1. **Rising Chronic Diseases**
#    - Cancer, diabetes, neurological, and chronic respiratory conditions show notable absolute death growth, consistent with global aging and lifestyle factors.
#
# 2. **Success Stories**
#    - HIV/AIDS and maternal/neonatal mortality have dropped significantly, indicating **effective interventions**.
#
# 3. **Rebounds & Resurgences**
#    - Cardiovascular diseases, unintentional injuries, and some infectious diseases show early improvements followed by a renewed climb—highlighting **complex** health challenges.
#
# 4. **Data & Demographic Influences**
#    - Absolute death counts are **not age-standardized**; some spikes may result from **population growth**, **shifts in demographics**, or **methodological changes** in data collection.
#
# In summary, the dataset reveals **diverse** mortality trajectories across diseases—some with clear progress, others with worrisome upticks—reflecting the **shifting landscape** of public health challenges over the last four decades.
